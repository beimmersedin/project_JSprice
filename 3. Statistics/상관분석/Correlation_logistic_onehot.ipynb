# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr, spearmanr, kendalltau
from scipy import stats
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

# %%
path = './data/'

df = pd.read_csv(path+'Coordinates_Preprocessed.csv')

# %%
# JS_Price를 5개의 범주로 나누고 기존 변수 삭제
df['JS_Price_Category'] = pd.cut(df['JS_Price'], bins=5, labels=False)
df.drop('JS_Price', axis=1, inplace=True)

# 범주형 변수 더미화 함수
def oh_encoding(df):
    # DataFrame의 복사본을 만듭니다.
    encoded_df = df.copy()
    for column in df.columns:
        if df[column].dtype == object:
            encoded_df = pd.get_dummies(encoded_df, columns=[column], prefix=column)
    return encoded_df

# 범주형 변수 더미화 적용
df_encoded = oh_encoding(df)

# 상관관계 분석을 위한 DataFrame 생성
result_df = pd.DataFrame(columns=['Column_Name', 'PCC', 'p-value'])

# 'JS_Price_Category'와 다른 열 간의 PCC 및 p-value 계산 및 저장
for column in df_encoded.columns:
    if column != 'JS_Price_Category':
        correlation, p_value = pearsonr(df_encoded['JS_Price_Category'], df_encoded[column])
        result_df = result_df.append({'Column_Name': column, 'PCC': correlation, 'p-value': p_value}, ignore_index=True)

# PCC 및 p-value를 기준으로 필터링
delete_columns = []

for index, row in result_df.iterrows():
    if abs(row['PCC']) < 0.1 or row['p-value'] > 0.05:
        delete_columns.append(row['Column_Name'])
delete_columns.append('JS_Price_Category')
        
# 선택된 특성 열
selected_features = list(set(df_encoded.columns) - set(delete_columns))

# %%
result_df.sort_values('PCC', ascending=False)
# Out:
#                     Column_Name       PCC        p-value
# 9                    Sell_Price  0.586392   0.000000e+00
# 1                         JS_BA  0.388496  7.817819e-180
# 4                      LC_index  0.217720   1.018361e-54
# 6                      TC_index  0.214449   4.207082e-53
# 5                      CA_index  0.212032   6.319917e-52
# 12                    YearMonth  0.211557   1.072842e-51
# 8                     HSP_index  0.209573   9.626457e-51
# 17              Region_Name_강남구  0.194690   6.664436e-44
# 31              Region_Name_서초구  0.154363   4.863025e-28
# 42             Building_Use_아파트  0.104752   1.121975e-13
# 37              Region_Name_용산구  0.089729   2.070177e-10
# 32              Region_Name_성동구  0.088180   4.214253e-10
# 34              Region_Name_송파구  0.078942   2.279018e-08
# 16    Shortest_Distance_to_Park  0.055374   8.944893e-05
# 15    Shortest_Distance_to_Univ  0.054213   1.254271e-04
# 22              Region_Name_광진구  0.018594   1.886508e-01
# 40               Region_Name_중구  0.018121   2.001368e-01
# 2                    Population  0.011226   4.274341e-01
# 39              Region_Name_종로구  0.009095   5.202593e-01
# 10                  Crime_Rates  0.007976   5.728625e-01
# 3                            UR -0.005898   6.767210e-01
# 29              Region_Name_마포구 -0.014393   3.089079e-01
# 35              Region_Name_양천구 -0.020090   1.555078e-01
# 30             Region_Name_서대문구 -0.020436   1.485012e-01
# 28              Region_Name_동작구 -0.026170   6.426056e-02
# 24              Region_Name_금천구 -0.033355   1.834408e-02
# 36             Region_Name_영등포구 -0.038085   7.073843e-03
# 19              Region_Name_강북구 -0.041920   3.029451e-03
# 33              Region_Name_성북구 -0.043995   1.860331e-03
# 21              Region_Name_관악구 -0.045357   1.336327e-03
# 18              Region_Name_강동구 -0.045390   1.325456e-03
# 41              Region_Name_중랑구 -0.045530   1.280440e-03
# 27             Region_Name_동대문구 -0.046638   9.709736e-04
# 38              Region_Name_은평구 -0.048487   6.042978e-04
# 26              Region_Name_도봉구 -0.056455   6.492620e-05
# 23              Region_Name_구로구 -0.064581   4.871930e-06
# 20              Region_Name_강서구 -0.066863   2.222906e-06
# 43           Building_Use_연립다세대 -0.067261   1.933251e-06
# 13  Shortest_Distance_to_Subway -0.068487   1.251976e-06
# 14  Shortest_Distance_to_School -0.075952   7.570622e-08
# 44            Building_Use_오피스텔 -0.076104   7.130269e-08
# 0                  Building_Age -0.083815   2.928448e-09
# 7                     SDT_index -0.086593   8.619823e-10
# 25              Region_Name_노원구 -0.091109   1.087932e-10
# 11                           IR -0.101376   6.715274e-13

# %%
selected_features
# Out:
# ['IR',
#  'Building_Use_아파트',
#  'Region_Name_서초구',
#  'HSP_index',
#  'YearMonth',
#  'LC_index',
#  'TC_index',
#  'CA_index',
#  'JS_BA',
#  'Sell_Price',
#  'Region_Name_강남구']
